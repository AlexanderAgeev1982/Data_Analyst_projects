# %% [markdown]
# # Комментарий ревьюера
# <div class="alert alert-block alert-info">
# Привет, Александр! Меня зовут Анвар Ганиев, и я буду проверять твой проект. Предлагаю общаться на «ты» :) Но если это не удобно - дай знать, и мы перейдем на "вы". Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать data scientist'ом.
#
# Видно, что ты старался, делая проект. Все ключевые этапы в работе выполнены, так что в целом справиться с задачей тебе удалось. Есть ещё несколько аспектов, которые требуют твоего внимания. Комментарии по ним помечены <span style='color:Red'> красным цветом  </span>. Комментарии я буду оставлять под ячейками, к которым они относятся. А еще писать в заголовке v{номер версии}, чтобы знать, при какой проверке, я их оставлял. После их доработки проект будет принят. Осталось совсем немного, буду ждать твою работу на повторное ревью 🙂
#
# <span style='color:Green'> Зелёным цветом </span> отмечены удачные и элегантные решения, на которые можно опираться в будущих проектах. <span style='color:Gold'> Жёлтым цветом </span>выделено то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас (однако это не обязательно).
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения. Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии. Всё это поможет выполнить повторную проверку твоего проекта оперативнее
# </div>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li><li><span><a href="#-Комментарий-студента-v1" data-toc-modified-id="-Комментарий-студента-v1-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span> Комментарий студента v1</a></span></li><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li><li><span><a href="#-Комментарий-студента-v1" data-toc-modified-id="-Комментарий-студента-v1-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span> Комментарий студента v1</a></span></li><li><span><a href="#-Комментарий-ревьюера-v2" data-toc-modified-id="-Комментарий-ревьюера-v2-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span> Комментарий ревьюера v2</a></span></li></ul></li><li><span><a href="#Общие-выводы:" data-toc-modified-id="Общие-выводы:-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общие выводы:</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span><ul class="toc-item"><li><span><a href="#-Итоговый-комментарий" data-toc-modified-id="-Итоговый-комментарий-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span> Итоговый комментарий</a></span></li><li><span><a href="#-Итоговый-комментарий-2" data-toc-modified-id="-Итоговый-комментарий-2-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span> Итоговый комментарий 2</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.

# %% [markdown]
# ## Подготовка данных

# %%
import pandas as pd 
from IPython.display import display 
pd.set_option('display.max_columns', None) #реализуем возможность вывода всех столбцов на экран
pd.set_option('display.float_format', '{:.3f}'.format) #выаодим значения float до 3 знаков после запятой

from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler 

from sklearn.model_selection import GridSearchCV 
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.dummy import DummyRegressor
from scipy import stats as st 
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_val_score

# %% [markdown]
# <div class="alert alert-success"> ✅
# <h3> Комментарий ревьюера v1</h3>
#
# Здорово, что все импорты находятся в одной ячейке. Если хочешь сделать ещё лучше, соблюдай стандарт PEP-8 =)
# Ссылка для ознакомления: https://pythonworld.ru/osnovy/pep-8-rukovodstvo-po-napisaniyu-koda-na-python.html#section-8

# %% [markdown]
# 1.1 Загрузим датасеты и выведем по 10 строк в каждом из них.

# %%
data_gtrain = pd.read_csv('/datasets/gold_recovery_train.csv', parse_dates = ['date'])
data_gtest = pd.read_csv('/datasets/gold_recovery_test.csv', parse_dates = ['date'])
data_gfull = pd.read_csv('/datasets/gold_recovery_full.csv', parse_dates = ['date'])
display(data_gtrain.head(10))
display(data_gtest.head(10))
display(data_gfull.head(10))
# Out:
#                  date  final.output.concentrate_ag  \
# 0 2016-01-15 00:00:00                        6.055
# 1 2016-01-15 01:00:00                        6.029
# 2 2016-01-15 02:00:00                        6.056
# 3 2016-01-15 03:00:00                        6.048
# 4 2016-01-15 04:00:00                        6.149
# 5 2016-01-15 05:00:00                        6.483
# 6 2016-01-15 06:00:00                        6.534
# 7 2016-01-15 07:00:00                        6.131
# 8 2016-01-15 08:00:00                        5.834
# 9 2016-01-15 09:00:00                        5.687
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                        9.890                         5.507
# 1                        9.969                         5.258
# 2                       10.214                         5.384
# 3                        9.977                         4.859
# 4                       10.143                         4.939
# ...

# %% [markdown]
# 1.2 необходимо посмотреть типы данных, кол-во столбцов, наличие пропусков и дубликатов в каждом data sets

# %%
print(data_gtrain.shape) # посомтрим кол-во столбцов и строк в каждо дада сете
print(data_gtest.shape)
print(data_gfull.shape)
data_gtrain.info()
print('дубликатов:', sum(data_gtrain.duplicated())) #считаем кол-во дубликатов
# столбцов 86, пропуски есть, дубликатов нет
# Out:
# (16860, 87)
# (5856, 53)
# (22716, 87)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16860 entries, 0 to 16859
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                16860 non-null  datetime64[ns]
#  1   final.output.concentrate_ag                         16788 non-null  float64
#  2   final.output.concentrate_pb                         16788 non-null  float64
#  3   final.output.concentrate_sol                        16490 non-null  float64
#  4   final.output.concentrate_au                         16789 non-null  float64
#  5   final.output.recovery                               15339 non-null  float64
#  6   final.output.tail_ag                                16794 non-null  float64
#  7   final.output.tail_pb                                16677 non-null  float64
# ...

# %%
data_gtest.info()
print('дубликатов:', sum(data_gtest.duplicated())) #считаем кол-во дубликатов
# столбцов 52, пропуски есть, дубликатов нет
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5856 entries, 0 to 5855
# Data columns (total 53 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        5856 non-null   datetime64[ns]
#  1   primary_cleaner.input.sulfate               5554 non-null   float64
#  2   primary_cleaner.input.depressant            5572 non-null   float64
#  3   primary_cleaner.input.feed_size             5856 non-null   float64
#  4   primary_cleaner.input.xanthate              5690 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_air      5840 non-null   float64
#  6   primary_cleaner.state.floatbank8_a_level    5840 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_air      5840 non-null   float64
#  8   primary_cleaner.state.floatbank8_b_level    5840 non-null   float64
# ...

# %%
data_gfull.info()
print('дубликатов:', sum(data_gfull.duplicated())) #считаем кол-во дубликатов
# столбцов 86, пропуски есть, дубликатов нет
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22716 entries, 0 to 22715
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                22716 non-null  datetime64[ns]
#  1   final.output.concentrate_ag                         22627 non-null  float64
#  2   final.output.concentrate_pb                         22629 non-null  float64
#  3   final.output.concentrate_sol                        22331 non-null  float64
#  4   final.output.concentrate_au                         22630 non-null  float64
#  5   final.output.recovery                               20753 non-null  float64
#  6   final.output.tail_ag                                22633 non-null  float64
#  7   final.output.tail_pb                                22516 non-null  float64
# ...

# %% [markdown]
# # Вывод
#  - Данные соответствуют описанию. Дубликатов нет. Всего 22716 объектов и 87 признаков
#  - Пропуски в данных требуют дальнейшего исследования.
#  - Типы данных соответствуют описанию.

# %% [markdown]
# 1.3 необходимо проверить расчёт эффективности обогащения на тренировочной выборке

# %%
# выделим нужные столбцы для расчета Recovery и MAE
mae_columns = ['rougher.output.recovery', 'rougher.output.concentrate_au', 'rougher.input.feed_au', 'rougher.output.tail_au']
# создадим датасет для проверки
mae_recovery = data_gtrain[mae_columns]
mae_recovery.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16860 entries, 0 to 16859
# Data columns (total 4 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   rougher.output.recovery        14287 non-null  float64
#  1   rougher.output.concentrate_au  16778 non-null  float64
#  2   rougher.input.feed_au          16777 non-null  float64
#  3   rougher.output.tail_au         14611 non-null  float64
# dtypes: float64(4)
# memory usage: 527.0 KB

# %% [markdown]
# 1.4 Необходимо избавиться от значений nan, так как метрика МАЕ не работает с таким типом данных

# %%
mae_recovery.dropna(inplace=True)
mae_recovery.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14287 entries, 0 to 16859
# Data columns (total 4 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   rougher.output.recovery        14287 non-null  float64
#  1   rougher.output.concentrate_au  14287 non-null  float64
#  2   rougher.input.feed_au          14287 non-null  float64
#  3   rougher.output.tail_au         14287 non-null  float64
# dtypes: float64(4)
# memory usage: 558.1 KB

# %% [markdown]
# 1.5 Посчитаем эффективности обогащения и MAE

# %%
def recovery(C, F, T): # напишем функцию для расчета эффективности обогащения  
    q = (C*(F-T))
    w =(F*(C-T))
    r = q / w * 100
    return r

# %%
t = mae_recovery['rougher.output.tail_au'] 
f = mae_recovery['rougher.input.feed_au']
c = mae_recovery['rougher.output.concentrate_au']
r = recovery(c, f, t)
print('MAE :', mean_absolute_error(mae_recovery['rougher.output.recovery'], r))
# Out:
# MAE : 9.303415616264301e-15

# %% [markdown]
# # Вывод по расчету
#  - MAE очень мала
#  - расчитанный в data_gtrain recovery максимально близок к верному и может быть применен как целевой признак.

# %% [markdown]
# <div class="alert alert-success"> ✅
# <h3> Комментарий ревьюера v1</h3>
#
# Верно, полученное значение оказалось в достаточной степени маленьким, чтобы можно было утверждать о правильности рассчёта.

# %% [markdown]
# 1.6 необходимо проанализировать какие признаки есть в data_gtrain и каких нет в data_gtest

# %%
set(data_gtrain.columns) - set(data_gtest.columns)
# Out:
# {'final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.recovery',
# ...

# %% [markdown]
# # Вывод
#  - в тестовых данных не хватает тех признаков, которые не могут быть посчитаны до получения финальных сплавов. В виду этого подобные признаки также не должны быть использованы при обучении модели.
#  - перед созданием модели их нужно убрать из обучающей выборки. Исключение составляют два целевых признака - final.output.recovery, rougher.output.recovery.

# %% [markdown]
# <div class="alert alert-success"> ✅
# <h3> Комментарий ревьюера v1</h3>
#
# Правильно, нельзя обучать на признаках, которые затем не будут доступны на тестах

# %% [markdown]
# ## Предобработка данных
# что необходимо сделать:
#  - исключить нулевые значения и nan из целевых признаков.
#  - заполнить пропуски в обучающих признаках.
#  - Добавить целевые признаки в тестовую выборку.
# Для начала проверим сколько пропусков есть в data_gtrain и в data_gtest

# %%
def nans (data):
    df = pd.DataFrame()
    df['count'] = data.isnull().sum()
    df['%'] = df['count'] / len(data)
    return df.sort_values('%', ascending=False)

nans(data_gtrain).head(10)
# Out:
#                                     count     %
# rougher.output.recovery              2573 0.153
# rougher.output.tail_ag               2250 0.133
# rougher.output.tail_sol              2249 0.133
# rougher.output.tail_au               2249 0.133
# secondary_cleaner.output.tail_sol    1986 0.118
# rougher.input.floatbank11_xanthate   1904 0.113
# final.output.recovery                1521 0.090
# primary_cleaner.input.sulfate        1307 0.078
# primary_cleaner.input.depressant     1262 0.075
# rougher.calculation.au_pb_ratio      1242 0.074

# %%
nans(data_gtest).head(10)
# Out:
#                                           count     %
# rougher.input.floatbank11_xanthate          353 0.060
# primary_cleaner.input.sulfate               302 0.052
# primary_cleaner.input.depressant            284 0.048
# rougher.input.floatbank10_sulfate           257 0.044
# primary_cleaner.input.xanthate              166 0.028
# rougher.input.floatbank10_xanthate          123 0.021
# rougher.input.feed_sol                       67 0.011
# rougher.input.floatbank11_sulfate            55 0.009
# rougher.input.feed_rate                      40 0.007
# secondary_cleaner.state.floatbank3_a_air     34 0.006

# %% [markdown]
# 2.1 сразу видно, что процент пропусков data_gtest меньше чем в data_gtrain.
#  - Для заполнения пропусков в обучающих признаках воспользуемся методом «ffill», он означает «прямое заполнение» (подсказка преподавателя в чате). Считаю правильным будет заполнить общий датасет, т.к. в нем содержатся все данные, идущие друг за другом.

# %%
# Необходимо отсортировать датасеты по дате
data_gtrain.sort_values(by='date', inplace=True)
data_gfull.sort_values(by='date', inplace=True)
data_gtest.sort_values(by='date', inplace=True)

# %%
row_test_columns = data_gtest.columns
train_columns = data_gtrain.columns.tolist()
train_columns.remove('final.output.recovery')
train_columns.remove('rougher.output.recovery')

# %%
data_gfull[train_columns] = data_gfull[train_columns].ffill(axis = 0) # заполняем только по обучающим признакам
data_gfull.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22716 entries, 0 to 22715
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                22716 non-null  datetime64[ns]
#  1   final.output.concentrate_ag                         22716 non-null  float64
#  2   final.output.concentrate_pb                         22716 non-null  float64
#  3   final.output.concentrate_sol                        22716 non-null  float64
#  4   final.output.concentrate_au                         22716 non-null  float64
#  5   final.output.recovery                               20753 non-null  float64
#  6   final.output.tail_ag                                22716 non-null  float64
#  7   final.output.tail_pb                                22716 non-null  float64
# ...

# %% [markdown]
# 2.2 Видно, что пропуски в обучающих признаках заполнены корректно, целевые признаки не затронуты. Теперь можно заполненить данных в остальных датасетах.

# %%
data_gtrain[train_columns] = data_gtrain[train_columns].ffill(axis = 0)
data_gtrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16860 entries, 0 to 16859
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                16860 non-null  datetime64[ns]
#  1   final.output.concentrate_ag                         16860 non-null  float64
#  2   final.output.concentrate_pb                         16860 non-null  float64
#  3   final.output.concentrate_sol                        16860 non-null  float64
#  4   final.output.concentrate_au                         16860 non-null  float64
#  5   final.output.recovery                               15339 non-null  float64
#  6   final.output.tail_ag                                16860 non-null  float64
#  7   final.output.tail_pb                                16860 non-null  float64
# ...

# %% [markdown]
# <div class="alert alert-success"> ✅
# <h3> Комментарий ревьюера v1</h3>
#
# Хорошо, что внимательно читаешь задание =) Тут было бы неправильно заполнять медианой или средним, так как значения фичей сильно зависят от этапа обработки

# %%
data_gtest.update(data_gtrain) # попробуем использовать метод update при заполнении пропусков
data_gtest['final.output.recovery'] = data_gtrain['final.output.recovery']
data_gtest['rougher.output.recovery'] = data_gtrain['rougher.output.recovery']
data_gtest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5856 entries, 0 to 5855
# Data columns (total 55 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        5856 non-null   datetime64[ns]
#  1   primary_cleaner.input.sulfate               5856 non-null   float64
#  2   primary_cleaner.input.depressant            5856 non-null   float64
#  3   primary_cleaner.input.feed_size             5856 non-null   float64
#  4   primary_cleaner.input.xanthate              5856 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_air      5856 non-null   float64
#  6   primary_cleaner.state.floatbank8_a_level    5856 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_air      5856 non-null   float64
#  8   primary_cleaner.state.floatbank8_b_level    5856 non-null   float64
# ...

# %% [markdown]
# # Вывод
#  Пропуски во всех датасетах заполнены

# %%
data_gtest.head() # проверим насколько корректно притянулись целевые признаки
# Out:
#                  date  primary_cleaner.input.sulfate  \
# 0 2016-01-15 00:00:00                        127.092
# 1 2016-01-15 01:00:00                        125.629
# 2 2016-01-15 02:00:00                        123.820
# 3 2016-01-15 03:00:00                        122.270
# 4 2016-01-15 04:00:00                        117.988
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                            10.128                            7.250
# 1                            10.296                            7.250
# 2                            11.316                            7.250
# 3                            11.322                            7.250
# 4                            11.914                            7.250
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                           0.989                                1549.776
# 1                           1.003                                1576.167
# ...

# %% [markdown]
# # Вывод
#  в тестовый датасет добавлены целевые признаки

# %% [markdown]
# 2.3 Теперь осталось удалить строки с целевыми признаками, значения которых пропущены или равны 0.

# %%
target = ['final.output.recovery', 'rougher.output.recovery']
data_gfull = data_gfull.dropna(subset=target)
data_gfull = data_gfull.loc[(data_gfull['final.output.recovery'] > 0) & (data_gfull['rougher.output.recovery'] > 0)]
data_gfull.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18949 entries, 0 to 22715
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                18949 non-null  datetime64[ns]
#  1   final.output.concentrate_ag                         18949 non-null  float64
#  2   final.output.concentrate_pb                         18949 non-null  float64
#  3   final.output.concentrate_sol                        18949 non-null  float64
#  4   final.output.concentrate_au                         18949 non-null  float64
#  5   final.output.recovery                               18949 non-null  float64
#  6   final.output.tail_ag                                18949 non-null  float64
#  7   final.output.tail_pb                                18949 non-null  float64
# ...

# %%
data_gtrain = data_gtrain.dropna(subset=target)
data_gtrain = data_gtrain.loc[(data_gtrain['final.output.recovery'] > 0) & (data_gtrain['rougher.output.recovery'] > 0)]
data_gtrain.info()

data_gtest = data_gtest.dropna(subset=target)
data_gtest = data_gtest.loc[(data_gtest['final.output.recovery'] > 0) & (data_gtest['rougher.output.recovery'] > 0)]
data_gtest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13795 entries, 0 to 16859
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                13795 non-null  datetime64[ns]
#  1   final.output.concentrate_ag                         13795 non-null  float64
#  2   final.output.concentrate_pb                         13795 non-null  float64
#  3   final.output.concentrate_sol                        13795 non-null  float64
#  4   final.output.concentrate_au                         13795 non-null  float64
#  5   final.output.recovery                               13795 non-null  float64
#  6   final.output.tail_ag                                13795 non-null  float64
#  7   final.output.tail_pb                                13795 non-null  float64
# ...

# %% [markdown]
# # Вывод по предобработке данных
#  - удалось выявить отсутствие ряда признаков в тестовой выборке. Основная причина – они характеризуют готовый продукт на определенной стадии, что никак не может быть получено во время технологического процесса.
#  - Пропуски обработаны и заменены. Пропуски в обучающих признаках в data_gfull и data_gtrain заменены ближними данными методом ffill, в тестовом наборе – заполнены из полной выборки методом update. Пропуски в целевых признаках удалены.
#  - удалось обнаружить нулевые значения в целевых признаках, а это не правильно, строки с ними пришлось удалить.
#  - В тестовую выборку добавлены целевые признаки.
#  - Проверку расчитанной в датасете эффективности обогащения провели. Получили малое MAE, что подтверждает корректность рассчитанных признаков.

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# 3.1 Сначала проанализируем динамику изменений концентрации металлов (Au, Ag, Pb) на различных этапах очистки.

# %%
data_gtrain = data_gtrain.set_index(pd.DatetimeIndex(data_gtrain.index))
data_gtest = data_gtest.set_index(pd.DatetimeIndex(data_gtest.index))

# %%
concentrate = {'ag':['rougher.output.concentrate_ag', 'primary_cleaner.output.concentrate_ag', 'final.output.concentrate_ag' ],
               'au':['rougher.output.concentrate_au', 'primary_cleaner.output.concentrate_au', 'final.output.concentrate_au' ],
               'pb':['rougher.output.concentrate_pb', 'primary_cleaner.output.concentrate_pb', 'final.output.concentrate_pb' ],
               'sol':['rougher.output.concentrate_sol', 'primary_cleaner.output.concentrate_sol', 'final.output.concentrate_sol']}
 
for q in concentrate:
    plt.figure(figsize=(10,6))
    sns.boxplot(data = data_gtrain[concentrate[q]])
    plt.title(f'Распределение доли {q} в концентрате на этапах очистки ')
    plt.show()

# %% [markdown]
# # Что получили:
#
#  - концентрация au закономерно возрастает от начального к конечному этапу - средние значения на финальном этапе находятся в районе 45 %, а это является самой большой величиной в концентрате. Изменение этих боксплотов закономерно показывает, что процесс идет успешно.
#  - концентрация серебра снижается в процессе обогащения. На финальном этапе среднее значение концентрации данного материала составляет около 5 %.
#  - динамика у свинца есть, но она незначительна в процессе обогащения, средние значения изменяются от 7.5 до 10 %. Возможно, на первом этапе очистки, свинец  добавляется в раствор искусственно, а дальше его объем не меняется.
#  - прочие примеси значительны после этапа флотации, но на этапе очистки доля этих примесей падает (средние значения уменьшаются почти в 3 раза), на втором этапе очистки содержание примесей почти не меняется.

# %% [markdown]
# 3.2 Теперь необходимо сравнить распределения гранул сырья на обучающей и тестовых выборках

# %%
fig = plt.figure(figsize=(17,6))
sns.distplot(data_gtest['rougher.input.feed_size']).set(xlim=(0,200))
sns.distplot(data_gtrain['rougher.input.feed_size']).set(xlim=(0,200))
plt.title('Распределение размера гранул на этапе флотации')
plt.xlabel('Размер гранул')
#z.set(xlim=(0,200))
plt.legend(labels=['data_gtrain','data_gtest'])
plt.show()

# %%
fig = plt.figure(figsize=(17,6))
sns.distplot(data_gtest['primary_cleaner.input.feed_size']).set(xlim=(0,10))
sns.distplot(data_gtrain['primary_cleaner.input.feed_size']).set(xlim=(0,10))
plt.title('Распределение размера гранул на первом этапе очистки')
plt.xlabel('Размер гранул')
plt.legend(labels=['data_gtrain','data_gtest'])
plt.show()

# %% [markdown]
# # Вывод:
# Распределения размеров гранул сырья на обучающей и тестовой выборках похожи. Любопытно, что перед primary этапом очистки размер гранул снижается больше, чем в 10 раз, что говорит об уменьшении их в размерах во время флотации.

# %% [markdown]
# <div class="alert alert-success"> ✅
# <h3> Комментарий ревьюера v1</h3>
#
# Верно. Хорошо, что построил масштабированные графики (`distplot`), так как количество данных в train/test датасетах отличается.
#
# Кстати, если тут провести ttest для этих выборок, то он скажет, что средние сильно отличаются и эти выборки из разных ГС. Но тут уже ничего не поделать, придется у заказчиков просить новые данные.

# %% [markdown]
# 3.3 Теперь проведем исследование общей концентрации веществ. Считаю, что нужно его провести в общем датасете. Необходимо произвести рассчет концентрации и построить гистограммы для выявления аномалий.

# %%
total_concentrate = {'rougher_input':['rougher.input.feed_ag', 'rougher.input.feed_pb', 'rougher.input.feed_sol', 'rougher.input.feed_au'],
               'rougher_output':['rougher.output.concentrate_ag', 'rougher.output.concentrate_pb', 'rougher.output.concentrate_sol', 'rougher.output.concentrate_au'],
               'primary_cleaner':['primary_cleaner.output.concentrate_ag', 'primary_cleaner.output.concentrate_pb', 'primary_cleaner.output.concentrate_sol', 'primary_cleaner.output.concentrate_au'],
               'final':['final.output.concentrate_ag', 'final.output.concentrate_pb', 'final.output.concentrate_sol', 'final.output.concentrate_au']}
for w in total_concentrate:
    plt.figure(figsize=(10,6))
    sns.distplot(np.sum(data_gfull[total_concentrate[w]], axis = 1))
    plt.title(f'Общая концентрация всех веществ на стадии {w}')
    plt.show()

# %% [markdown]
# # Вывод:
#  - Общая концентрация веществ увеличивается по ходу процесса обогащения.
#  - на этапе первой очистки наблюдаем нулевые значения, однако для остальных этапов нулевые значения практически отсутствуют и не вдияют на распределение. Мы не будем удалять их.

# %% [markdown]
# <div class="alert alert-warning"> ⚠️
# <h3> Комментарий ревьюера v1</h3>
#
# Нулевая суммарная концетрация выглядит как ошибка в данных, я бы удалил

# %% [markdown]
# # Выводы по анализу данных:
#  - концентрация au возрастает в процессе обогащения.
#  - концентрация ag и sol примесей закономерно падает.
#  - концентрация pb не значительно меняется.
#  - распределения размеров гранул сырья на обучающей и тестовых выборках схожи между собой. Это означает, что оценка модели будет правильной. Перед этапом первой очистки размер гранул снижается значительно, что говорит об их дброблении во время этапа флотации.
#  - общая концентрация веществ увеличивается. Могу предположить, что при обработке вымываются лишние примеси.
#  - на этапе первой очистки наблюдаем нулевые значения, однако для остальных этапов нулевые значения практически отсутствуют и не вдияют на распределение. Мы не будем удалять их.

# %% [markdown]
# ## Модель

# %% [markdown]
# 4.1 Напишем функцию для вычисления итоговой sMAPE

# %%
def smape (target, predictions):
    q = abs(predictions - target)
    w = (abs(target) + abs(predictions)) / 2
    total = (q / w).sum()
    smape = (1 / len(target)) * total * 100
    return smape

# %% [markdown]
# <div class="alert alert-success"> ✅
# <h3> Комментарий ревьюера v1</h3>
#
# Хорошо, что делаешь все рассчеты векторно, а не в цикле. Иначе это будет занимать достаточно много времени.

# %% [markdown]
# 4.2 Обученим модели. Предварительно разделим модели на признаки и их масштабирование.

# %%
rougher_features = []  # создадим список признаков для этапа флотации
for column in row_test_columns:
    if "rougher" in column:
        rougher_features.append(column)
        
rougher_features_train = data_gtrain[rougher_features]
rougher_target_train = data_gtrain['rougher.output.recovery']
display(rougher_features_train.head())
#print(rougher_target_train.head())

# готовим признаки для финального этапа
#final_features_train = data_gtrain[data_gtrain.columns].drop(['rougher.output.recovery','final.output.recovery', 'date'], axis=1)
final_features_train = data_gtrain[data_gtrain.columns].drop(['rougher.output.recovery','final.output.recovery', 'date', 'final.output.concentrate_ag', 'final.output.concentrate_au', 'final.output.concentrate_pb', 'final.output.concentrate_sol',
 'final.output.tail_ag',
 'final.output.tail_au',
 'final.output.tail_pb',
 'final.output.tail_sol',
 'primary_cleaner.output.concentrate_ag',
 'primary_cleaner.output.concentrate_au',
 'primary_cleaner.output.concentrate_pb',
 'primary_cleaner.output.concentrate_sol',
 'primary_cleaner.output.tail_ag',
 'primary_cleaner.output.tail_au',
 'primary_cleaner.output.tail_pb',
 'primary_cleaner.output.tail_sol',
 'rougher.calculation.au_pb_ratio',
 'rougher.calculation.floatbank10_sulfate_to_au_feed',
 'rougher.calculation.floatbank11_sulfate_to_au_feed',
 'rougher.calculation.sulfate_to_au_concentrate',
 'rougher.output.concentrate_ag',
 'rougher.output.concentrate_au',
 'rougher.output.concentrate_pb',
 'rougher.output.concentrate_sol',
 'rougher.output.tail_ag',
 'rougher.output.tail_au',
 'rougher.output.tail_pb',
 'rougher.output.tail_sol',
 'secondary_cleaner.output.tail_ag',
 'secondary_cleaner.output.tail_au',
 'secondary_cleaner.output.tail_pb',
 'secondary_cleaner.output.tail_sol'], axis=1)
final_target_train = data_gtrain['final.output.recovery']

display(final_features_train.head())

# готовим тестовые выборки
rougher_test_features = data_gtest[rougher_features]
rougher_test_target = data_gtest['rougher.output.recovery']
final_features_test = data_gtest.drop(['rougher.output.recovery','final.output.recovery', 'date'], axis=1)
final_target_test = data_gtest['final.output.recovery']
display(final_features_test.head())
# Out:
#                                rougher.input.feed_ag  rougher.input.feed_pb  \
# 1970-01-01 00:00:00.000000000                  6.100                  2.285
# 1970-01-01 00:00:00.000000001                  6.161                  2.266
# 1970-01-01 00:00:00.000000002                  6.116                  2.160
# 1970-01-01 00:00:00.000000003                  6.043                  2.038
# 1970-01-01 00:00:00.000000004                  6.061                  1.787
#
#                                rougher.input.feed_rate  \
# 1970-01-01 00:00:00.000000000                  523.546
# 1970-01-01 00:00:00.000000001                  525.291
# 1970-01-01 00:00:00.000000002                  530.027
# 1970-01-01 00:00:00.000000003                  542.590
# 1970-01-01 00:00:00.000000004                  540.532
#
#                                rougher.input.feed_size  \
# 1970-01-01 00:00:00.000000000                   55.487
# 1970-01-01 00:00:00.000000001                   57.279
# ...

# %% [markdown]
# 4.3 проведем масштабирование признаков на этапe флотации

# %%
rougher_scaler = StandardScaler()
rougher_scaler.fit(rougher_features_train)

rougher_column_train = rougher_features_train.columns
rougher_column_test = rougher_test_features.columns

rougher_features_train = rougher_scaler.transform(rougher_features_train)
rougher_features_train = pd.DataFrame(rougher_features_train, columns = rougher_column_train)

rougher_test_features = rougher_scaler.transform(rougher_test_features)
rougher_test_features = pd.DataFrame(rougher_test_features, columns = rougher_column_test)

# %% [markdown]
# 4.4 проведем масштабирование признаков на финальном этапе

# %%
final_scaler = StandardScaler()
final_scaler.fit(final_features_train)

final_column_train = final_features_train.columns
final_column_test = final_features_test.columns

final_features_train = final_scaler.transform(final_features_train)
final_features_train = pd.DataFrame(final_features_train, columns = final_column_train)

final_features_test = final_scaler.transform(final_features_test)
final_features_test = pd.DataFrame(final_features_test, columns = final_column_test)

# %% [markdown]
# 4.5 Напишем функцию для оценки качества модели с помощью кросс-валидации.

# %%
def cross_val (model, features, target):
    scores = cross_val_score(model, features, 
                                   target, scoring=make_scorer(smape, greater_is_better=True), cv=5,n_jobs=-1)
    smape_result = np.mean(scores)
    return smape_result

# %% [markdown]
# <div class="alert alert-warning"> ⚠️
# <h3> Комментарий ревьюера v1</h3>
#
# Немного про кастомный скоринг и `greater_is_better=False`: вот очень хорошая статья - https://kiwidamien.github.io/custom-loss-vs-custom-scoring.html
#
# Если кратко, то твой результат при использовании cross_val_score со своей метрикой и флагом `greater_is_better=False` остается таким же, только с отрицательным значением, так как есть метрика (по которой мы выбираем модель) и есть лосс (по которой обучается модель). Так вот make_scorer создает метрику из лосса, по которой ты выбираешь лучшую модель, но сама модель будет обучаться по встроенной функции потерь (скорее всего MSE), так что это нужно только для выбора модели. Просто принято ставить флаг greater_is_better=False для метрик, которые являются лоссами (не все метрики лоссы, например, recall, precision и тп).
#
# НО если ты используешься гридсерч, то `greater_is_better=False` нужно указывать обязательно, так как best_estimator_ выбирает лучшую модель по метрике уже самостоятельно =)

# %%
# Напишем функцию для вывода sMAPE каждого этапа и финальной sMAPE.

def ml(model):
    smape_rougher = cross_val (model, rougher_features_train, rougher_target_train)
    smape_final = cross_val (model, final_features_train, final_target_train)
    smape_end = 0.25 * smape_rougher + 0.75 * smape_final
    print('sMAPE на этапе флотации составила', smape_rougher)
    print('sMAPE на финальном этапе составила', smape_final)
    print('Конечная оценка sMAPE составила', smape_end)

# %% [markdown]
# 4.6 Необходимо рассчитать sMAPE с помощью моделей линейной регрессии, решающего дерева и случайного леса. Лучшую модель проверим на адекватность с помощью случайной модели при помощи DummyRegressor.

# %%
model = LinearRegression()
ml(model)
# Out:
# sMAPE на этапе флотации составила 6.465260362220198
# sMAPE на финальном этапе составила 11.030694678155701
# Конечная оценка sMAPE составила 9.889336099171826

# %%
model = DecisionTreeRegressor()
ml(model)
# Out:
# sMAPE на этапе флотации составила 12.009770769634464
# sMAPE на финальном этапе составила 16.497337503636746
# Конечная оценка sMAPE составила 15.375445820136177

# %%
model = RandomForestRegressor()
ml(model)
# Out:
# sMAPE на этапе флотации составила 6.623798452349708
# sMAPE на финальном этапе составила 9.731699824260355
# Конечная оценка sMAPE составила 8.954724481282694

# %%
model = DummyRegressor()
ml(model)
# Out:
# sMAPE на этапе флотации составила 7.804618399753869
# sMAPE на финальном этапе составила 10.447654847065328
# Конечная оценка sMAPE составила 9.786895735237463

# %% [markdown]
# 4.7 Сделаем перебор гмперпараметров модели Случайный лес

# %%
best_smape = 10
est_est = 0
best_depth = 0
for est in range(10, 51, 10):
    for depth in range (1, 5):
        model = RandomForestRegressor(n_estimators=est, max_depth=depth)
        smape_rougher = cross_val (model, rougher_features_train, rougher_target_train)
        smape_final = cross_val (model, final_features_train, final_target_train)
        smape_end = 0.25 * smape_rougher + 0.75 * smape_final
        if smape_end < best_smape:
            best_smape = smape_end
            best_est = est
            best_depth = depth
print('Наилучшая модель с sMAPE {}, Случайного лес \
с количеством деревьев {} и глубиной {}'.format(best_smape, best_est, best_depth))
# Out:
# Наилучшая модель с sMAPE 8.420148230225054, Случайного лес с количеством деревьев 10 и глубиной 4

# %% [markdown]
# <div class="alert alert-success"> ✅
# <h3> Комментарий ревьюера v1</h3>
#
# Здорово, что сравниваешь модель с константной! Из одного значения метрики не ясно, насколько адекватны предсказания моделей

# %% [markdown]
# # Выводы по моделям на тренировочной выборке
# - из рассчета видно, что случайный лес имеет наилучшую среднюю оценку качества на всех этапах отгрубой очистки до получения конечного продукта (6.65; 9.79; 9.01).
# - эти показатели лучше случайной dummy модели

# %% [markdown]
# <div class="alert alert-danger"> ❌
# <h3> Комментарий ревьюера v1</h3>
#
# Использовать модели только с дефолтными гиперпараметрами - как-то несерьезно. Сделай, пожалуйста, перебор гиперпараметров хотя бы для рандом фореста. Можешь использовать гридсерч, там также есть параметр scoring, куда можно написать свой кастомный скорер.
#
# PS Обычный GridSearchCV довольно долго делает расчеты, так как проверяет все комбинации. На практике обычно какие-то параметры сильно важнее других, поэтому по ним нет особого смысла итерироваться, поэтому рекомендую использовать RandomizedSearchCV.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <h3> Комментарий студента v1</h3>
#
# Анвар большое спасибо за рекомендации и подсказки. Я их обязательно на выходные изучу и покопаюсь в документации.
# Я использовал перебор гиперпараметров на Случайном лесе и полученные результаты использовал на тестовой выборке (n-estimators=20, depth=4)

# %% [markdown]
# 4.7 построим модели на тестовой выборке, так как она показала меньши  и следовательно лучшие результаты и сравним их качество с Dummy моделью

# %%
# напишем функцию для проверки на тестовой выборке
def ml_test(model):
    model_rougher = model
    model_rougher.fit(rougher_features_train, rougher_target_train)
    predictions_rougher = model_rougher.predict(rougher_test_features)
    

    model_final = model
    model_rougher.fit(final_features_train, final_target_train)
    predictions_final = model_final.predict(final_features_test)
    
    smape_rougher = smape(rougher_test_target, predictions_rougher)
    smape_final = smape(final_target_test, predictions_final)
    smape_end = 0.25 * smape_rougher + 0.75 * smape_final
    print('Средняя оценка качества по кросс-валидации на этапе флотации составила', smape_rougher)
    print('Средняя оценка качества по кросс-валидации на финальном этапе составила', smape_final)
    print('Конечная оценка качества по кросс-валидации составила', smape_end)

# %%
model = RandomForestRegressor(n_estimators=20, max_depth=4)
ml_test(model)
# Out:
# Средняя оценка качества по кросс-валидации на этапе флотации составила 6.397858937762335
# Средняя оценка качества по кросс-валидации на финальном этапе составила 8.027346020524583
# Конечная оценка качества по кросс-валидации составила 7.619974249834021

# %%
model = DummyRegressor()
ml_test(model)
# Out:
# Средняя оценка качества по кросс-валидации на этапе флотации составила 8.862238336259445
# Средняя оценка качества по кросс-валидации на финальном этапе составила 9.915200900455352
# Конечная оценка качества по кросс-валидации составила 9.651960259406374

# %% [markdown]
# <div class="alert alert-warning"> ⚠️
# <h3> Комментарий ревьюера v1</h3>
#
# Я бы для такой задачки еще использовал catboost. Советую почитать-поразбираться, как эта штука запускается. Примерно так же, как рандом форест, на самом деле. И еще он может "съесть" категориальные фичи (например, страну и тп). Оставлю ссылочку на статью на Хабре:
# https://habr.com/ru/company/otus/blog/527554/
#
# Еще можно попробовать регрессионые модели с регуляризацией: Ridge, Lasso. Они отличаются только тем, что у одной модели L1, а у второй L2 регуляризация. И еще есть ElasticNet с комбинацией L1 и L2

# %% [markdown]
# <div class="alert alert-block alert-info">
# <h3> Комментарий студента v1</h3>
#
# Результат после переборки изменился, но так или иначе sMAPE меньше на Случайном лесе и качество лучше случайной Dummy модели на тестовой выборке.
# Общие выводы также поправил.

# %% [markdown]
# <div class="alert alert-success"> ✅
# <h3> Комментарий ревьюера v2</h3>
#
# 👍

# %% [markdown]
# # Выводы по модели случайного леса на тестовой выборке
# - из рассчета видно, что наша модель случайного леса имеет среднюю оценку качества на всех этапах очистки лучше, чем показатели Dummy модели.
# - Модель Случайный лес может быть рекомендована как наилучшая для предсказания и ее качество проверено на тестовой выборке

# %% [markdown]
# ## Общие выводы:
#  - Данные соответствуют описанию. Дубликатов нет.
#  - Пропуски в данных потребовали дальнейшего исследования.
#  - Типы данных соответствуют описанию.
#  - произведен рассчет MAE, которая оказалась очень мала
#  - расчитанный в data_gtrain recovery максимально близок к верному и может быть применен как целевой признак.
#  - удалось выявить отсутствие ряда признаков в тестовой выборке. Основная причина – они характеризуют готовый продукт на определенной стадии, что никак не может быть получено во время технологического процесса.
#  - Пропуски обработаны и заменены. Пропуски в обучающих признаках в data_gfull и data_gtrain заменены ближними данными методом ffill, в тестовом наборе – заполнены из полной выборки методом update. Пропуски в целевых признаках удалены.
#  - удалось обнаружить нулевые значения в целевых признаках, а это не правильно, строки с ними пришлось удалить.
#  - В тестовую выборку добавлены целевые признаки.
#  - Проверку расчитанной в датасете эффективности обогащения провели. Получили малое MAE, что подтверждает корректность рассчитанных признаков.
#  - В результате анализа данных, выявлены следующие закономерности: концентрация au закономерно возрастает от начального к конечному этапу - средние значения на финальном этапе находятся в районе 45 %, а это является самой большой величиной в концентрате. Изменение этих боксплотов закономерно показывает, что процесс идет успешно.
#  - концентрация серебра снижается в процессе обогащения. На финальном этапе среднее значение концентрации данного материала составляет около 5 %.
#  - динамика у свинца есть, но она незначительна в процессе обогащения, средние значения изменяются от 7.5 до 10 %. Возможно, на первом этапе очистки, свинец  добавляется в раствор искусственно, а дальше его объем не меняется.
#  - прочие примеси значительны после этапа флотации, но на этапе очистки доля этих примесей падает (средние значения уменьшаются почти в 3 раза), на втором этапе очистки содержание примесей почти не меняется.
#  - при сравнении распределения гранул сырья на обучающей и тестовых выборках получили следующую картину: Распределения размеров гранул сырья на обучающей и тестовой выборках похожи. Любопытно, что перед primary этапом очистки размер гранул снижается больше, чем в 10 раз, что говорит об уменьшении их в размерах во время флотации.
#  - Общая концентрация веществ увеличивается по ходу процесса обогащения.
#  - на этапе первой очистки наблюдаем нулевые значения, однако для остальных этапов нулевые значения практически отсутствуют и не вдияют на распределение. Мы не будем удалять их.
#  - Удалось обучить несколько моделей на тренировочной выборке: DecisionTreeRegressor(), RandomForestRegressor() и LinearRegression(). Наилучшее качество показала модель Случайного леса. Ее результаты проверили на адекватность через случайную Dummy модель. После этого выбрали Случайный лес как лучшая моджель и проверено качество на тестовой выборке. Также проверили на адекватность через случайную модель. Случайный лес показал и здесь лучшее качество.Средняя оценка качества по кросс-валидации на этапе флотации составила 6.397858937762335, Средняя оценка качества по кросс-валидации на финальном этапе составила 8.027346020524583, Конечная оценка качества по кросс-валидации составила 7.619974249834021
#  - как итог: построен прототип модели машинного обучения для предсказания коэффициента восстановления золота из золотосодержащей руды

# %% [markdown]
# ## Чек-лист готовности проекта

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [ ]  Весь код выполняется без ошибок
# - [ ]  Ячейки с кодом расположены в порядке выполнения
# - [ ]  Выполнен шаг 1: данные подготовлены
#     - [ ]  Проверена формула вычисления эффективности обогащения
#     - [ ]  Проанализированы признаки, недоступные в тестовой выборке
#     - [ ]  Проведена предобработка данных
# - [ ]  Выполнен шаг 2: данные проанализированы
#     - [ ]  Исследовано изменение концентрации элементов на каждом этапе
#     - [ ]  Проанализированы распределения размеров гранул на обучающей и тестовой выборках
#     - [ ]  Исследованы суммарные концентрации
# - [ ]  Выполнен шаг 3: построена модель прогнозирования
#     - [ ]  Написана функция для вычисления итогового *sMAPE*
#     - [ ]  Обучено и проверено несколько моделей
#     - [ ]  Выбрана лучшая модель, её качество проверено на тестовой выборке

# %% [markdown]
# <div class="alert alert-block alert-info">
# <h3> Итоговый комментарий</h3>
#
# Большое спасибо за проделанную работу. Видно, что приложено много усилий. Работа в целом и каждый шаг в отдельности сделаны хорошо. Я оставил несколько советов, надеюсь они будут учтены в этом или будущих проектах. Осталось добавить перебор гиперпараметров хотя бы для 1 модели, затем я смогу принять проект.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <h3> Итоговый комментарий 2</h3>
#
# Теперь все ок =) Успехов в следующих проектах!
