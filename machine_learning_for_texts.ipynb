# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Комментарий ревьюера</b>
#
#
# Привет, Александр! Давай знакомиться! Меня зовут Дмитрий Махортов, и я буду проверять твой проект. Сразу предлагаю общение на «ты» 🙂, но если тебе это не комфортно, то дай знать, и мы перейдем на «вы».
#
# Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе погрузиться в увлекательный мир работы с данными и вырасти в крепкого профи. Это отдаленная цель. А ближайшая - сделать твою работу еще лучше )).
#
#
# Все ключевые этапы в работе выполнены, и я вижу что с проектом ты справшяешься. Есть моменты, которые нужно доработать, но я уверен, у тебя все получится.
#
# Расскажу как обычно проходит проверка:
# Бывают моменты, которые требуют пристального внимания. Комментарии по ним выделены <span style='background-color:#F7B3A4'> красным цветом </span> и обозначены значком 🛑. После их доработки проект будет принят.  🙂
#
# <span style='background-color:#B7EBA7'> Зеленым цветом </span> и значком ✅ отмечены удачные и элегантные решения, на которые можно опираться в будущих проектах. Или советы «со звездочкой», которые помогут тебе в будущем.
#
# <span style='background-color:#F9EDA6'>Жёлтым цветом </span> и значком ⚠️ выделено то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас (однако это не обязательно).
#
# Давай работать над проектом в диалоге: **если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом**. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения. Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта оперативнее.
# </div>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка" data-toc-modified-id="Подготовка-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка</a></span></li><li><span><a href="#Подготовка-признаков-и-целевого-признака-перед-обучением" data-toc-modified-id="Подготовка-признаков-и-целевого-признака-перед-обучением-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Подготовка признаков и целевого признака перед обучением</a></span><ul class="toc-item"><li><span><a href="#-Комментарий-студента-v1" data-toc-modified-id="-Комментарий-студента-v1-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span> Комментарий студента v1</a></span></li><li><span><a href="#-Комментарий-студента-v1" data-toc-modified-id="-Комментарий-студента-v1-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span> Комментарий студента v1</a></span></li></ul></li><li><span><a href="#Обучение" data-toc-modified-id="Обучение-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Обучение</a></span><ul class="toc-item"><li><span><a href="#-Комментарий-студента-v1" data-toc-modified-id="-Комментарий-студента-v1-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span> Комментарий студента v1</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Выводы</a></span><ul class="toc-item"><li><span><a href="#-Комментарий-студента-v1" data-toc-modified-id="-Комментарий-студента-v1-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span> Комментарий студента v1</a></span></li></ul></li><li><span><a href="#Чек-лист-проверки" data-toc-modified-id="Чек-лист-проверки-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Чек-лист проверки</a></span></li></ul></div>

# %% [markdown]
# # Проект для «Викишоп»

# %% [markdown]
# Интернет-магазин «Викишоп» запускает новый сервис. Теперь пользователи могут редактировать и дополнять описания товаров, как в вики-сообществах. То есть клиенты предлагают свои правки и комментируют изменения других. Магазину нужен инструмент, который будет искать токсичные комментарии и отправлять их на модерацию.
#
# Обучите модель классифицировать комментарии на позитивные и негативные. В вашем распоряжении набор данных с разметкой о токсичности правок.
#
# Постройте модель со значением метрики качества *F1* не меньше 0.75.
#
# **Инструкция по выполнению проекта**
#
# 1. Загрузите и подготовьте данные.
# 2. Обучите разные модели.
# 3. Сделайте выводы.
#
# Для выполнения проекта применять *BERT* необязательно, но вы можете попробовать.
#
# **Описание данных**
#
# Данные находятся в файле `toxic_comments.csv`. Столбец *text* в нём содержит текст комментария, а *toxic* — целевой признак.

# %% [markdown]
# ## Подготовка

# %% [markdown]
# 1.1 загружаем необходимые библиотеки

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import re
from pymystem3 import Mystem
import nltk
from nltk.corpus import stopwords as nltk_stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.ensemble import RandomForestClassifier
from lightgbm import LGBMClassifier
from sklearn.tree import DecisionTreeClassifier
from catboost import CatBoostClassifier
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score, roc_auc_score, roc_curve
from sklearn.utils import shuffle
import warnings
warnings.filterwarnings('ignore')
import time

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Отлично, все нужные библиотеки импортированы в начале ноутбука.Это хорошая практика.</div>

# %%
pd.options.display.max_colwidth = 500 # выведем побольше символов в ячейках

# %%
df = pd.read_csv('/datasets/toxic_comments.csv')
df.head(10)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   text  \
# ...

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  👍 </div>

# %%
display(df['toxic'].value_counts())
class_frequency = df['toxic'].value_counts()[0] / df['toxic'].value_counts()[1]
class_frequency
# Out:
# 0    143346
# 1     16225
# Name: toxic, dtype: int64
# 8.834884437596301

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Молодец, исследован баланс классов. Это полезная информация, может пригодиться.</div>

# %% [markdown]
# # Вывод:
# - Классы несбалансированы. Необходимо провести поиск лучшего способа балансировки и сравнить качество

# %% [markdown]
# ## Подготовка признаков и целевого признака перед обучением

# %%
def clear_text(text):
    clear_text = re.sub(r'[^a-zA-Z ]', ' ', text).split()
    clear_text = ' '.join(clear_text)
    return(clear_text)

# %%
df['text'] = df['text'].apply(clear_text)

# %%
#%%time

#m = Mystem()

#def lemmatize_text(text):
    #text = text.lower()
    #lemm_text = "".join(m.lemmatize(text))
   # cleared_text = re.sub(r'[^a-zA-Z]', ' ', lemm_text) 
    #return " ".join(cleared_text.split())

#df['lemm_text'] = df['text'].apply(lemmatize_text)

#df = df.drop(['text'], axis=1)
#del m
# Out:
# CPU times: user 31.4 s, sys: 6.73 s, total: 38.1 s
# Wall time: 1min 23s

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
# Ты используешь лемматайзер pymystem3. Но этот лемматайзер предназначен для русского языка и здесь бесполезен. Для английского языка существует множество лемматизаторов: WordNetLemmatizer (+POS тег) или SpaCy. Можно посмотреть например вот эту статью:
#
# https://webdevblog.ru/podhody-lemmatizacii-s-primerami-v-python/
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <h3> Комментарий студента v1</h3>
#
# Дмитрий привет! Спасибо за замечание. Я решил вообще не использовать лемматайзер, но на выходных покопаюсь в статье и поизучаю лемматайзеры для англ языка.

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Комментарий ревьюера v2</b>
#
# ОК, принял. Но тогда лучше сразу попробуй разобраться со Spacy, это активно используемая в индустрии библиотека.</div>

# %% [markdown]
# # 2.1 Необходимо разобить выборку в пропорции 60/20/20, а также уменьшить количество кроссвалидаций до 3 из-за размера выборки.

# %%
target = df['toxic']
features = df.drop(['toxic'], axis=1)

features_train, features_valid, target_train, target_valid = train_test_split(features, 
                                                                              target, 
                                                                              test_size=0.4, 
                                                                              random_state=12082020)
features_valid, features_test, target_valid, target_test = train_test_split(features_valid, 
                                                                            target_valid, 
                                                                            test_size=0.5,
                                                                            random_state=12082020)

nltk.download('stopwords')
stopwords = set(nltk_stopwords.words('english'))

count_tf_idf = TfidfVectorizer(stop_words=stopwords)

#features_train = count_tf_idf.fit_transform(features_train['lemm_text'].values.astype('U'))
#features_valid = count_tf_idf.transform(features_valid['lemm_text'].values.astype('U'))
#features_test = count_tf_idf.transform(features_test['lemm_text'].values.astype('U'))

features_train = count_tf_idf.fit_transform(features_train['text'].values)
features_valid = count_tf_idf.transform(features_valid['text'].values)
features_test = count_tf_idf.transform(features_test['text'].values)

print(features_train.shape)
print(features_valid.shape)
print(features_test.shape)
cv_counts = 3
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# (95742, 125392)
# (31914, 125392)
# (31915, 125392)

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
# Нет смысла менять кодировку. Изменение кодировки увеличивает количество оперативной памяти, необходимой для хранения текстов. Но наши тексты написаны латиницей, поэтому вполне достаточно кодировки по умолчанию.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <h3> Комментарий студента v1</h3>
#
# оставил кодировку по умолчанию.

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# <b>v2</b> ОК </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# 👍 Молодец, получил признаки из текстов с помощью TF-IDF. И совершенно верно обучил наш векторайзер на обучающем наборе и применил его к тестовому</div>

# %%
# %%time

classificator = LogisticRegression()
train_f1 = cross_val_score(classificator, 
                      features_train, 
                      target_train, 
                      cv=cv_counts, 
                      scoring='f1').mean()
print('F1 на CV', train_f1)
# Out:
# F1 на CV 0.6731417395333228
# CPU times: user 46.7 s, sys: 57.3 s, total: 1min 43s
# Wall time: 1min 46s

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# А вот с кросс-валидацией очень тонкий момент. Ты помнишь, что векторайзер мы обучали на обучающей выборке а применяли к тестовой и валидационной. Что происходит при кросс-валидации? Ты разбиваешь большую обучающую выборку на несколько фолдов, из них выделяешь часть на обучение, часть на валидацию.  Но признаки (TF-IDF) уже обучены на всем наборе (обучающий + валидационный). Получается утечка данных. Чтобы избежать её нужно использовать pipeline из векторайзера и модели.
#
# Пример такого пайплайна можно посмотреть в официальной документации
#
#   https://scikit-learn.org/stable/auto_examples/model_selection/grid_search_text_feature_extraction.html
# </div>

# %% [markdown]
# # 2.2 Изменение баланса классов
#  - Изменение весов классов

# %%
# %%time

dict_classes={0:1, 1:class_frequency}
classificator = LogisticRegression(class_weight=dict_classes)
train_f1_balanced = cross_val_score(classificator, 
                                    features_train, 
                                    target_train, 
                                    cv=cv_counts, 
                                    scoring='f1').mean()
print('F1 на CV с балансированными классами', train_f1_balanced)
# Out:
# F1 на CV с балансированными классами 0.7553763830132558
# CPU times: user 31.5 s, sys: 1min 9s, total: 1min 40s
# Wall time: 1min 40s

# %%
# %%time

classificator = LogisticRegression(class_weight='balanced')
train_f1_balanced = cross_val_score(classificator, 
                                    features_train, 
                                    target_train, 
                                    cv=cv_counts, 
                                    scoring='f1').mean()
print('F1 на CV с балансированными классами', train_f1_ballanced)
# Out:
# F1 на CV с балансированными классами 0.7553763830132558
# CPU times: user 18.5 s, sys: 39.3 s, total: 57.7 s
# Wall time: 57.8 s

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Крайне сложно понять логику твоего исследования. Мне пришлось догадываться, что трижды запуская кросс-валидацию ты изучаешь влияние аргумента class_weight на целевую метрику. Лучше явно написать, что и зачем ты делаешь, иначе следить за проектом очень тяжело.
# </div>

# %% [markdown]
# # Вывод
#  - на обучающей выборке F1-мера увеличилась. Встроенный метод повторяет значение F1

# %% [markdown]
# # 2.3 Ресемплирование с уменьшением класса 0
#  - Сделаем количество записей с классом 0 таким же, как и количество записей с классом 1.

# %%
toxic_comments_train = df.iloc[target_train.index]

target_train_class_zero = toxic_comments_train[toxic_comments_train['toxic'] == 0]['toxic']
target_train_class_one = toxic_comments_train[toxic_comments_train['toxic'] == 1]['toxic']

# %%
target_train_class_zero_downsample = target_train_class_zero.sample(target_train_class_one.shape[0],
                                                                    random_state=12082020)
target_train_downsample = pd.concat([target_train_class_zero_downsample, target_train_class_one])

features_train_downsample = df.iloc[target_train_downsample.index]
features_train_downsample, target_train_downsample = shuffle(features_train_downsample,
                                                             target_train_downsample,
                                                             random_state=12082020)
features_train_downsample = count_tf_idf.transform(features_train_downsample['lemm_text']
                                                   .values.astype('U'))
del count_tf_idf
del stopwords

# %%
classificator = LogisticRegression()
train_f1_downsampled = cross_val_score(classificator,
                      features_train_downsample, 
                      target_train_downsample, 
                      cv=cv_counts, 
                      scoring='f1').mean()
print('F1 на CV с уменьшением классов', train_f1_downsampled)
# Out:
# F1 на CV с уменьшением классов 0.8841371052721447

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# К сожалению увеличение метрики f1 в данном случае "обманчиво". Чтобы сравнить две модели нужно оценивать их на одном наборе данных (и такой набор у тебя есть - валидационный). А сейчас произошло следующее: при кросс-валидации и обучающий и валидационный фолды у тебя сбалансированные. А большинство моделей показыают лучшую метрику f1 на сбалансированном датасете, чем на имеющем дисбаланс.
# </div>

# %% [markdown]
# # Вывод
#  - прирост F1 получился ощутимый.

# %% [markdown]
# 1.6 Нужно выбрать метод балансировки по весу и удалить ненужные переменные.

# %%
del toxic_comments_train
del target_train_class_zero
del target_train_class_one
del target_train_class_zero_downsample
del target_train_downsample
del features_train_downsample

# %% [markdown]
# # Вывод
#
# В ходе преподготовки были получены признаки для обучения и разделена выборка на обучающуи тестовую.
# На тестировании оптимальными показателями F1 обладает классификатор, где учтен вес классов. Данные подготовлены, можем переходить к обучению

# %% [markdown]
# ## Обучение

# %% [markdown]
# # 3.1 Логистическая регрессия

# %%
# %%time
best_model = None
best_result = 0
best_с = 0
for reg in np.linspace(0.0001, 100, 20):
    model = LogisticRegression(random_state=12345, solver='liblinear', C=reg)
    model.fit(features_train, target_train) # обучим модель на трейне
    predictions = model.predict(features_valid) # получим предсказания на валидационной выборке
    result = f1_score(target_valid, predictions) # определим качество модели
    print(result)
    if result > best_result:
        best_model = model
        best_result = result
        best_с = reg
print('Наилучшее F1 {:.3f} при регуляризации {}'.format(best_result, best_с))
# Out:
# 0.0
# 0.7779162956366875
# 0.782791185729276
# 0.7834836918806385
# 0.7813632441760138
# 0.7794218857536133
# 0.7787883988330186
# 0.776559287183002
# 0.7757057313943541
# 0.7763180344651084
# 0.7746550843127236
# 0.7732063923835429
# 0.7716856221354608
# 0.7704029800203183
# 0.7694129588902048
# 0.7682947439580867
# 0.7681134943421718
# 0.7679324894514767
# 0.7672849915682968
# 0.7656276326874474
# Наилучшее качество модели 0.783 при регуляризации 15.789557894736841
# CPU times: user 2min 22s, sys: 4min 31s, total: 6min 53s
# Wall time: 6min 54s

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# 👍 Всё верно. Грамотный подбор гиперпараметра, обучение на обучающей выборке и оценка на валидационной. </div>

# %% [markdown]
# # 3.2 LightGBM

# %%
best_model = None
best_result = 0
best_est = 0
best_leaves = 0
best_rate = 0
for est in [50, 100, 500]:
    for leave in [21, 31, 41, 51]:
        for rate in [0.01, .04, 0.06, 0.3]:
            model = LGBMClassifier(random_state=12345, 
                                     n_estimators=est, 
                                     num_leaves=leave, learning_rate = rate)
            model.fit(features_train, target_train) 
            predictions = model.predict(features_valid)
            result = f1_score(target_valid, predictions) # определим качество модели на валидационной выборке
            print(result)
            if result > best_result:
                best_model = model
                best_result = result
                best_est = est
                best_leaves = leave
                best_rate = rate

print("F1 на валидационной выборке:", best_result, 
      "Количество деревьев:", best_est, "Скорость обучения:", best_rate,
     "Количество листьев", best_leaves)
# Out:
# 0.0
# 0.6101052631578948
# 0.6417330880850195
# 0.7531861425237838
# 0.0
# 0.6389854776027818
# 0.6754731861198738
# 0.765017667844523
# 0.0
# 0.6665341812400637
# 0.6960878782038928
# 0.767233818628311
# 0.0
# 0.6794896957801766
# 0.7078972407231209
# 0.7724904480722473
# 0.54763491005996
# 0.6591594610898854
# 0.700887688151293
# 0.7682026028842772
# 0.5682463419960692
# 0.7006172839506173
# 0.7233245975290152
# 0.7719114828367312
# 0.5824152084683517
# 0.7150690111552278
# 0.7356998344675374
# 0.7737806987201661
# 0.5962891874600128
# 0.7244593586875466
# 0.7444060396579952
# 0.7744710132461724
# 0.6823992133726648
# 0.7603454480028787
# 0.7708148411148589
# 0.7766122098022357
# 0.7122507122507123
# 0.7715249423042784
# 0.7758469369843778
# 0.7765429988032142
# 0.7268319970165952
# 0.7733990147783252
# 0.7769834350479512
# 0.7737525632262474
# 0.7346713312465477
# 0.7772711329358121
# 0.77802885451069
# 0.7689413374380023
# ...

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# 👍 </div>

# %% [markdown]
# # 3.3 CatBoost

# %%
best_model = None
best_result = 0
best_iter = 0
best_rate = 0
for iter in [150, 500]:
  for rate in [0.01, .04, 0.06, 0.3, 0.5]:
    model = CatBoostClassifier(random_state=12345, 
                                     iterations=iter, learning_rate = rate) # инициализируем модель
    model.fit(features_train, target_train) # обучим модель на тренировочной выборке
    predictions = model.predict(features_valid)
    result = f1_score(target_valid, predictions) # посчитаем качество модели на валидационной выборке
    print(result)
    if result > best_result:
      best_model = model
      best_result = result
      best_iter = iter
      best_rate = rate

print("F1 наилучшей модели на валидационной выборке:", best_result, 
      "Количество иттераций:", best_iter, "Скорость обучения:", best_rate)
# Out:
# 0:	learn: 0.6832487	total: 2.38s	remaining: 5m 54s
# 1:	learn: 0.6726016	total: 4.15s	remaining: 5m 6s
# 2:	learn: 0.6625278	total: 6s	remaining: 4m 53s
# 3:	learn: 0.6526711	total: 7.77s	remaining: 4m 43s
# 4:	learn: 0.6431079	total: 9.59s	remaining: 4m 38s
# 5:	learn: 0.6335118	total: 11.4s	remaining: 4m 33s
# 6:	learn: 0.6242075	total: 13.2s	remaining: 4m 29s
# 7:	learn: 0.6152820	total: 14.9s	remaining: 4m 24s
# 8:	learn: 0.6068585	total: 16.8s	remaining: 4m 23s
# 9:	learn: 0.5984052	total: 18.6s	remaining: 4m 20s
# 10:	learn: 0.5896750	total: 20.4s	remaining: 4m 17s
# 11:	learn: 0.5814010	total: 22.2s	remaining: 4m 15s
# 12:	learn: 0.5735841	total: 24s	remaining: 4m 12s
# 13:	learn: 0.5656778	total: 25.8s	remaining: 4m 10s
# 14:	learn: 0.5576866	total: 27.7s	remaining: 4m 9s
# 15:	learn: 0.5503394	total: 29.4s	remaining: 4m 6s
# 16:	learn: 0.5434221	total: 31.3s	remaining: 4m 4s
# 17:	learn: 0.5357335	total: 33.2s	remaining: 4m 3s
# ...

# %% [markdown]
# # Выводы
# - Проведено обучение моделей
# - Обучены модели: логистическая регрессия, LightGBM, CatBoost.
# - Целевая метрика достигнута на всех трех моделях
# - лучший результат достингут на модели Логистическая регрессия

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# 👍 </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Рекомендую написать выводы, какая модель лучшая по  результатам исследований на валидации и явно указать модель и все подобранные гиперпараметры.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <h3> Комментарий студента v1</h3>
#
# проставил промежуточный вовод по итогам обучения моделей

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# <b>v2</b> ОК </div>

# %% [markdown]
# # 3.4 Теперь посмотрим какой показатель возможно получить на тесте

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# К данному этапу честнее с одной выбранной моделью (ты это сделал). Чтобы избежать искушения вдруг "поменять" модель по  результатам тестирования. Ведь любое использование тестовой выборки для улучшения модели (в том числе выбор лучшей модели) - это нарушение.
#
# Если интересно - можно оценить и другие модели по тестовой выборке, но "вне зачета". Т.е. никаким образом не использовать эту информацию.
# </div>

# %% [markdown]
# - создадим таблицу для хранения результатов

# %%
d = {'model': [], 'F_1':[], 'fit_time': [], 'predict_time':[]}
results = pd.DataFrame(data=d)
results
# Out:
# Empty DataFrame
# Columns: [model, F_1, fit_time, predict_time]
# Index: []

# %%
def model_res(model_name, model):
    f_1, fit_time, pred_time = ml(model)
    results.loc[len(results)] = [model_name, f_1, fit_time, pred_time]
    if len(results) > 0: # исключим дублировании при неоднократном выполнении функции для одной и той же модели
        results.drop_duplicates(inplace=True)

# %% [markdown]
# - создадим функцию для добавления результатов в таблицу

# %%
def ml (model):
    start_fit_time = time.time()
    model.fit(features_train, target_train)
    stop_fit_time = time.time()
    
    fit_time = stop_fit_time - start_fit_time
    
    start_predict_time = time.time()
    predictions = model.predict(features_test)
    
    stop_predict_time = time.time()
    
    pred_time = stop_predict_time - start_predict_time
    
    f_1 = f1_score(target_test, predictions)
    
    return f_1, fit_time, pred_time

# %% [markdown]
# - Логистическая регрессия

# %%
lr = LogisticRegression(random_state=12345, solver='liblinear', C=10.526405263157894)
model_res('LogisticRegression', lr)
display(results)
# Out:
#                 model       F_1  fit_time  predict_time
# 0  LogisticRegression  0.769443  15.30421       0.00344

# %% [markdown]
# - LightGBM

# %%
lgbm = LGBMClassifier(learning_rate=0.06, n_estimators=500, num_leaves=21, random_state=12345)
model_res('LGBMClassifier', lgbm)
display(results)
# Out:
#                 model       F_1     fit_time  predict_time
# 0  LogisticRegression  0.769443    15.304210      0.003440
# 1      LGBMClassifier  0.762205  1450.555099      9.449613
# 2      LGBMClassifier  0.762205   607.997624      9.286295

# %% [markdown]
# - CatBoost

# %%
cb = CatBoostClassifier(learning_rate=0.06, 
                         iterations=500,
                         random_state=12345)
model_res('CatBoostClassifier', cb)
display(results)
# Out:
# 0:	learn: 0.6346622	total: 2.45s	remaining: 20m 23s
# 1:	learn: 0.5823441	total: 4.33s	remaining: 17m 59s
# 2:	learn: 0.5355715	total: 6.31s	remaining: 17m 25s
# 3:	learn: 0.4969658	total: 8.2s	remaining: 16m 56s
# 4:	learn: 0.4622407	total: 10.2s	remaining: 16m 48s
# 5:	learn: 0.4320859	total: 12.1s	remaining: 16m 35s
# 6:	learn: 0.4074671	total: 14s	remaining: 16m 25s
# 7:	learn: 0.3862242	total: 16.1s	remaining: 16m 30s
# 8:	learn: 0.3664690	total: 18.1s	remaining: 16m 25s
# 9:	learn: 0.3499191	total: 20s	remaining: 16m 20s
# 10:	learn: 0.3360420	total: 22.1s	remaining: 16m 20s
# 11:	learn: 0.3230379	total: 24.2s	remaining: 16m 23s
# 12:	learn: 0.3121923	total: 26.2s	remaining: 16m 20s
# 13:	learn: 0.3025472	total: 28.1s	remaining: 16m 14s
# 14:	learn: 0.2938877	total: 30s	remaining: 16m 11s
# 15:	learn: 0.2865490	total: 32s	remaining: 16m 6s
# 16:	learn: 0.2800938	total: 33.9s	remaining: 16m 3s
# 17:	learn: 0.2741605	total: 36s	remaining: 16m 3s
# ...

# %%
results
# Out:
#                 model       F_1     fit_time  predict_time
# 0  LogisticRegression  0.769443    15.304210      0.003440
# 1      LGBMClassifier  0.762205  1450.555099      9.449613
# 2      LGBMClassifier  0.762205   607.997624      9.286295
# 3  CatBoostClassifier  0.713994   936.101084      0.316750

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# 👍 Нужная точность на тесте достигнута </div>

# %% [markdown]
# ## Выводы
# - Данные подготовлены и обработаны
# - в ходе подготовки были получены признаки для обучения и разделена выборка на обучающуи тестовую.
# - На тестировании оптимальными показателями F1 обладает классификатор, где учтен вес классов.
# - Проведено обучение моделей
# - Обучены модели: логистическая регрессия, LightGBM, CatBoost.
# - Проведено тестирование моделей
# - Поставленная метрика достигнута с помощью Логистической регрессии.

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Я вижу, что порог преодлоели несколько моделей, но лучшее качество дает логистическая регрессия. Пожалуйста, исправь выводы.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <h3> Комментарий студента v1</h3>
#
# вывод поправил. Глаз немного замылился.., спасибо за замечание)

# %% [markdown]
# ## Чек-лист проверки

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [ ]  Весь код выполняется без ошибок
# - [ ]  Ячейки с кодом расположены в порядке исполнения
# - [ ]  Данные загружены и подготовлены
# - [ ]  Модели обучены
# - [ ]  Значение метрики *F1* не меньше 0.75
# - [ ]  Выводы написаны

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Заключительный комментарий</b>
# Давай подведем итоги. В целом с проектом ты справился - текст предобработан, извлечены признаки и обучены классификаторы. Достигнуто требуемое значение метрики f1.
#
# Но кое с чем нужно еще поработать. Во первых, стоит навести порядок с лемматизацией - или вообще убрать упоминание о ней, либо сделать с помощью подходящих библиотек.
# Во вторых не стоит перекодировать английский текст в Юникод.
#
# Желтые комментарии на твое усмотрение.
#
# Жду твоих исправлений :)
# </div>

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Заключительный комментарий v2</b>
# Ошибка с лемматизацией и изменением кодировки исправлена. Теперь проект может быть принят.
# Поздравляю и желаю дальнейших успехов!
# </div>
